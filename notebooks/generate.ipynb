# %%
# [1/3] Mount Google Drive & Setup Path
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.insert(0, '/content/drive/MyDrive/code')

print('Project root: /content/drive/MyDrive/code')

# %%
# [2/3] Install Dependencies
# !pip uninstall tensorflow tensorflow-text tensorflow-hub -y -q 2>/dev/null
# !pip install -q transformers peft accelerate bitsandbytes "torch>=2.0" "torchao>=0.16.0" 2>/dev/null
# !pip install -q evaluate smatchpp nltk python-Levenshtein bert_score rouge_score absl-py z3-solver 2>/dev/null
import nltk
nltk.download('punkt', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)
nltk.download('punkt_tab', quiet=True)

import torch, transformers, peft
print(f'torch={torch.__version__}')
print(f'transformers={transformers.__version__}')
print(f'peft={peft.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')

# %%
# [3/3] Run Inference — change dataset_name / model_name to switch
# dataset_name: "test", "test_folio", "test_willow"
# model_name:   "Qwen4b", "Qwen8b", "Ministral8b"
# NOTE: Metrics NOT computed here. Run evaluate.ipynb to compute metrics.
from src.run_inference import run_inference

run_inference("test", model="Qwen8b")
