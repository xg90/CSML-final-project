# %%
# [1/3] Mount Google Drive & Setup Path
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.insert(0, '/content/drive/MyDrive/code')

print('Project root: /content/drive/MyDrive/code')

# %%
# [2/3] Install Dependencies
# NOTE: `-U peft` is required — the Ministral adapter was saved with PEFT 0.20.0.
# !pip install -q -U transformers peft accelerate bitsandbytes "torchao>=0.16.0" 2>/dev/null

import torch, transformers, peft
print(f'torch={torch.__version__}')
print(f'transformers={transformers.__version__}')
print(f'peft={peft.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')

# %%
# [3/3] Run T=0 (greedy) single-candidate inference for Ministral8b
# dataset: "test", "val", "train", "test_folio", "test_willow"
from src.generate_t0_ministral import run_t0_ministral

results = run_t0_ministral("test", n_samples=1000)

print(f"Done: {len(results)} sentences generated. Showing only the last entry:")
results[-1]
